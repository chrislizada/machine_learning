# %%
# Loading Images
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("images/plane.jpg", cv2.IMREAD_GRAYSCALE)

plt.imshow(image, cmap="gray"), plt.axis("off")
plt.show()

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image
# Out:
# array([[212, 212, 212, ..., 204, 204, 204],
#        [212, 212, 212, ..., 204, 204, 204],
#        [213, 213, 213, ..., 204, 204, 204],
#        ...,
#        [108, 108, 108, ...,  20,  20,  20],
#        [108, 108, 108, ...,  20,  20,  20],
#        [107, 107, 107, ...,  20,  20,  20]],
#       shape=(846, 1024), dtype=uint8)

# %%
image.shape
image[0,0]
# Out:
# np.uint8(212)

# %%
image_bgr = cv2.imread("images/plane.jpg", cv2.IMREAD_COLOR)
image_bgr[0,0]

plt.imshow(image_bgr), plt.axis("off")
plt.show()

# %%
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb), plt.axis("off")
plt.show()

# %%
# Saving Images
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("images/plane.jpg", cv2.IMREAD_GRAYSCALE)

cv2.imwrite("images/plane_gray.jpg", image)
# Out:
# True

# %%
# Resizing Images
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("images/plane.jpg", cv2.IMREAD_GRAYSCALE)

image_50x50 = cv2.resize(image, (50,50))

plt.imshow(image_50x50, cmap="gray"), plt.axis("off")
plt.show()

# %%
# Cropping Images
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("images/plane.jpg", cv2.IMREAD_GRAYSCALE)

image_cropped = image[:,:423]

plt.imshow(image_cropped, cmap="gray"), plt.axis("off")
plt.show()

# %%
# Blurring Images
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)

image_blurry = cv2.blur(image, (15,15))

plt.imshow(image_blurry, cmap="gray"), plt.axis("off")
plt.show()

# %%
image_very_blurry = cv2.blur(image, (100,100))

plt.imshow(image_very_blurry, cmap="gray"), plt.xticks([]), plt.yticks([])
plt.show()
